# %% [markdown]
# **AIM:**
#
# To write a python program for K-means algorithm using iris dataset.

# %% [markdown]
# **Algorithm**
#
# 1.Import necessary libraries and load the iris dataset using datasets.load_iris().
#
# 2.Create a Pandas DataFrame from the iris dataset and name the columns.
#
# 3.Create another Pandas DataFrame for the target variable and name the column as 'Targets'.
#
# 4.Initialize a KMeans model with n_clusters=3.
#
# 5.Fit the KMeans model on the iris dataset.
#
# 6.Define a np.array with colors for the plot.
#
# 7.Create a figure and plot the original classification in subplot(1, 2, 1).
#
# 8.Create another plot and plot the KMeans model classification in subplot(1, 2, 2).
#
# 9.Calculate and print the accuracy score and confusion matrix of the KMeans model.
# 10.Scale the iris dataset using StandardScaler() from preprocessing.
#
# 11.Initialize a GaussianMixture model with n_components=3.
#
# 12.Fit the GMM model on the scaled dataset (xs).
#
# 13.Predict labels for the xs dataset using the GMM model.
#
# 14.Create the GMM plot in subplot(2, 2, 3).
#
# 15.Calculate and print the accuracy score and confusion matrix of the GMM model.

# %% [markdown]
# **K-means Algorithm & Gaussian Mixture Model**
#
# EM algorithm to cluster a set of data stored in a .CSV file. Use the same data set for clustering using k-Means algorithm. Compare the results of these two algorithms and comment on the quality of clustering. You can add Java/Python ML library classes/API in the program.

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
import sklearn.metrics as sm
import pandas as pd
import numpy as np
import io

# %%
iris = datasets.load_iris()

# %%
X = pd.DataFrame(iris.data)
X.columns = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width']

y = pd.DataFrame(iris.target)
y.columns = ['Targets']

model = KMeans(n_clusters=3)
model.fit(X)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
plt.figure(figsize=(14,7))

colormap = np.array(['red', 'lime', 'black'])

# Plot the Original Classifications
plt.subplot(1, 2, 1)
plt.scatter(X.Petal_Length, X.Petal_Width, c=colormap[y.Targets], s=40)
plt.title('Real Classification')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
# Plot the Models Classifications
plt.subplot(1, 2, 2)
plt.scatter(X.Petal_Length, X.Petal_Width, c=colormap[model.labels_], s=40)
plt.title('K Mean Classification')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
print('The accuracy score of K-Mean: ',sm.accuracy_score(y, model.labels_))
print('The Confusion matrixof K-Mean: ',sm.confusion_matrix(y, model.labels_))
# Out:
# The accuracy score of K-Mean:  0.8933333333333333
# The Confusion matrixof K-Mean:  [[50  0  0]
#  [ 0 48  2]
#  [ 0 14 36]]

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
scaler.fit(X)
xsa = scaler.transform(X)
xs = pd.DataFrame(xsa, columns = X.columns)
xs.sample(5)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 108      1.038005    -1.282963      1.160620     0.790671
# 60      -1.021849    -2.433947     -0.146641    -0.262387
# 137      0.674501     0.098217      0.990108     0.790671
# 69      -0.294842    -1.282963      0.080709    -0.130755
# 43      -1.021849     1.019004     -1.226552    -0.788916

# %%
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=3)
gmm.fit(xs)

y_gmm = gmm.predict(xs)

# %%
 ... plt.subplot(2, 2, 3)
plt.scatter(X.Petal_Length, X.Petal_Width, c=colormap[y_gmm], s=40)
plt.title('GMM Classification')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
print('The accuracy score of EM: ',sm.accuracy_score(y, y_gmm))
print('The Confusion matrix of EM: ',sm.confusion_matrix(y, y_gmm))
# Out:
# The accuracy score of EM:  0.35333333333333333
# The Confusion matrix of EM:  [[ 5  0 45]
#  [ 2 48  0]
#  [ 0 50  0]]
